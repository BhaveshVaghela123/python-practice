# %%
class dog:
    attr="mammal"

    def __init__(self,name):
        self.name=name
        print("dog name is",self.name)

rodger=dog("rodger")
tommy=dog("tommy")

print("my dog is",rodger.attr)
# Out:
# dog name is rodger
# dog name is tommy
# my dog is mammal

# %%
#creat a class amploy having instanst veriable are employ id name and salary initialize that object and show all the object details using UDF
#creat 3 objects

class employee:
    def __init__(self,eid,ename,esal):
        self.eid=eid
        self.ename=ename
        self.esal=esal

    def show(self):
        print("employee id",self.eid)
        print("employee name",self.ename)
        print("employee sal",self.esal)

e1=employee(123,"raxit",12000)
e1.show()
# Out:
# employee id 123
# employee name raxit
# employee sal 12000

# %%
#creat a class calculater which does all the arethmetic operastions in that each operastion will be done by class method or function

class calculator:
    def add(self,a,b):
        return a+b

c=calculator()
a=int(input("enter num"))
b=int(input("enter num"))
print("add of 2 number is",c.add(a,b))
# Out:
# enter num 2
# enter num 3
# add of 2 number is 5

# %%
#wap toimplement single queue using class object where for insertion,deletion and display should be done using UDF amd make 
#menu base d
